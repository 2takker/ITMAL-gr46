# %% [markdown]
# # ITMAL Exercise
#
# REVISIONS| |
# ---------| |
# 2018-0301| CEF, initial.
# 2018-0305| CEF, updated.
# 2018-0306| CEF, updated and spell checked.
# 2018-0306| CEF, major overhaul of functions.
# 2018-0306| CEF, fixed problem with MNIST load and Keras.
# 2018-0307| CEF, modified report functions and changed Qc+d.
# 2018-0311| CEF, updated Qd.
# 2018-0312| CEF, added grid and random search figs and added bullets to Qd.
#
# ## Hyperparameters and Gridsearch
#
# When instantiating a Scikit-learn model in python most or all constructor parameters have _default_ values. These values are not part of the internal model and are hence called ___hyperparametes___---in contrast to _normal_ model parameters, say the weights, $\mathbf w$, for an `SGD` model.
#
# An example could be the python constructor for the support-vector classifier `sklearn.svm.SVC`, with, say the `kernel` hyperparameter having the default value `'rbf'`. If you should choose, what would you set it to other than `'rbf'`?
#
# ```python
# class sklearn.svm.SVC(
#     C=1.0,
#     kernel=’rbf’,
#     degree=3,
#     gamma=’auto_deprecated’,
#     coef0=0.0,
#     shrinking=True,
#     probability=False,
#     tol=0.001,
#     cache_size=200,
#     class_weight=None,
#     verbose=False,
#     max_iter=-1,
#     decision_function_shape=’ovr’,
#     random_state=None
#   )
# ```
#
# The default values might be sensible a general starting point, but for your data, you might want to optimize the hyperparameters to yield a better result.
#
# To be able to set `kernel` to a sensible value you need to go into the documentation for the `SVC` and understand what the kernel represents and what values it can be set to, and you need to understand the consequences of setting `kernel` to something different than the default...and the story repeats for every other hyperparameter!
#
# An alternative is just to __brute-force__ a search of interesting hyperparameters, an choosing the 'best' parameters according to a fit-predict and some performance metric, say 'f1'.
#
# Now, you just pick out some hyperparameters, that you figure are important, set then to a suitable range, say
#
# ```python
#     'kernel':('linear', 'rbf'),
#     'C':[1, 10]
# ```
# and fire up a full (grid) search on this hyperparameter set, that will try out all combination of `kernel` and `C` for the model, and then prints the hyperparameter set with the highest score...
#
# <img src="Figs/gridsearch.png" style="width:300px">
# <small><em>
#     <center> Conceptual graphical view of grid search for two distinct hyperparameters. </center>
#     <center> Notice that you would normally search hyperparameters like `alpha` with an exponential range, say [0.01, 0.1, 1, 10] or similar.</center>
# </em></small>
#
# The demo code below sets up some of our well known 'hello-world' data and run a _grid search_ on a particular model, here a _support-vector classifier_ (SVC)
#
# Other models and datasets  ('mnist', 'iris', 'moon') can also be examined.
#
#
# ### Qa Explain GridSearchCV
#
# There are two code cells below: 1:) function setup, 2) the actual grid-search.
#
# Review the code cells and write a __short__ summary. Mainly focus on __cell 2__, but dig into cell 1 if you find it interesting (notice the use of local-function, a nifty feature in python).
#
# In detail, examine the lines:
#
# ```python
# grid_tuned = GridSearchCV(model, tuning_parameters, ..
# grid_tuned.fit(X_train, y_train)
# ..
# FullReport(grid_tuned , X_test, y_test, time_gridsearch)
# ```
# and write a short description of how the `GridSeachCV` works: explain how the search parameter set is created and the overall search mechanism (without going into to much detail)
#
# What role does the parameter `scoring='f1_micro'` play in the `GridSearchCV`, and what does `n_jobs=-1` mean?

# %%
# TODO: Qa, code review..cell 1) function setup
import sys,os
#Add the folder above current workspace to the sys.path variable
sys.path.append(os.path.join(os.getcwd(), '..')) # OS inspecific

from time import time
import numpy as np

from sklearn import svm
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn import datasets

#from libitmal import utils as itmalutils
from libitmal import dataloaders_v2 as itmaldataloaders

currmode="N/A" # GLOBAL var!

def SearchReport(model): 
    
    def GetBestModelCTOR(model, best_params):
        def GetParams(best_params):
            r=""          
            for key in sorted(best_params):
                value = best_params[key]
                t = "'" if str(type(value))=="<class 'str'>" else ""
                if len(r)>0:
                    r += ','
                r += f'{key}={t}{value}{t}'  
            return r            
        try:
            p = GetParams(best_params)
            return type(model).__name__ + '(' + p + ')' 
        except:
            return "N/A(1)"
        
    print("\nBest model set found on train set:")
    print()
    print(f"\tbest parameters={model.best_params_}")
    print(f"\tbest '{model.scoring}' score={model.best_score_}")
    print(f"\tbest index={model.best_index_}")
    print()
    print(f"Best estimator CTOR:")
    print(f"\t{model.best_estimator_}")
    print()
    try:
        print(f"Grid scores ('{model.scoring}') on development set:")
        means = model.cv_results_['mean_test_score']
        stds  = model.cv_results_['std_test_score']
        i=0
        for mean, std, params in zip(means, stds, model.cv_results_['params']):
            print("\t[%2d]: %0.3f (+/-%0.03f) for %r" % (i, mean, std * 2, params))
            i += 1
    except:
        print("WARNING: the random search do not provide means/stds")
    
    global currmode                
    assert "f1_micro"==str(model.scoring), f"come on, we need to fix the scoring to be able to compare model-fits! Your scoreing={str(model.scoring)}...remember to add scoring='f1_micro' to the search"   
    return f"best: dat={currmode}, score={model.best_score_:0.5f}, model={GetBestModelCTOR(model.estimator,model.best_params_)}", model.best_estimator_ 

def ClassificationReport(model, X_test, y_test, target_names=None):
    assert X_test.shape[0]==y_test.shape[0]
    print("\nDetailed classification report:")
    print("\tThe model is trained on the full development set.")
    print("\tThe scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, model.predict(X_test)                 
    print(classification_report(y_true, y_pred, target_names))
    print()
    
def FullReport(model, X_test, y_test, t):
    print(f"SEARCH TIME: {t:0.2f} sec")
    beststr, bestmodel = SearchReport(model)
    ClassificationReport(model, X_test, y_test)    
    print(f"CTOR for best model: {bestmodel}\n")
    print(f"{beststr}\n")
    return beststr, bestmodel
    
def LoadAndSetupData(mode, test_size=0.3):
    assert test_size>=0.0 and test_size<=1.0
    
    def ShapeToString(Z):
        n = Z.ndim
        s = "("
        for i in range(n):
            s += f"{Z.shape[i]:5d}"
            if i+1!=n:
                s += ";"
        return s+")"

    global currmode
    currmode=mode
    print(f"DATA: {currmode}..")
    
    if mode=='moon':
        X, y = itmaldataloaders.MOON_GetDataSet(n_samples=5000, noise=0.2)
        itmaldataloaders.MOON_Plot(X, y)
    elif mode=='mnist':
        X, y = itmaldataloaders.MNIST_GetDataSet(fetchmode=False)
        if X.ndim==3:
            X=np.reshape(X, (X.shape[0], -1))
    elif mode=='iris':
        X, y = itmaldataloaders.IRIS_GetDataSet()
    else:
        raise ValueError(f"could not load data for that particular mode='{mode}'")
        
    print(f'  org. data:  X.shape      ={ShapeToString(X)}, y.shape      ={ShapeToString(y)}')

    assert X.ndim==2
    assert X.shape[0]==y.shape[0]
    assert y.ndim==1 or (y.ndim==2 and y.shape[1]==0)    
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=0, shuffle=True
    )
    
    print(f'  train data: X_train.shape={ShapeToString(X_train)}, y_train.shape={ShapeToString(y_train)}')
    print(f'  test data:  X_test.shape ={ShapeToString(X_test)}, y_test.shape ={ShapeToString(y_test)}')
    print()
    
    return X_train, X_test, y_train, y_test

print('OK')
# Out:
# OK

# %%
# TODO: Qa, code review..cell 2) the actual grid-search

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData('iris') # or 'moon', or 'mnist'

# Setup search parameters
model = svm.SVC(gamma="scale")

tuning_parameters = {
    'kernel':('linear', 'rbf'), 
    'C':[1, 10]
}

CV=5
VERBOSE=0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model, tuning_parameters, cv=CV, scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
grid_tuned.fit(X_train, y_train)
t = time()-start

# Report result
b0, m0= FullReport(grid_tuned , X_test, y_test, t)
print('OK')


# C1 opsætter et format at afraportere resultaterne af et grid search
# C2 Henter/klargør dataset, opsætter parametre der skal testes, 
# udfører et grid search og raporterer resultatet

# Grid search afprøver givne hyperparametre og finder hvilke parametre som giver den laveste loss-function
# Dette gøres via krydsvalidering. Sættes scoring til 'f1_micro', søges der efter mindste f1-score. 
# n_jobs = -1, køres gridsearch på alle processorer.
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
#
# SEARCH TIME: 1.38 sec
#
# Best model set found on train set:
#
# 	best parameters={'C': 1, 'kernel': 'linear'}
# 	best 'f1_micro' score=0.9714285714285714
# 	best index=0
#
# Best estimator CTOR:
# 	SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.971 (+/-0.048) for {'C': 1, 'kernel': 'linear'}
# 	[ 1]: 0.962 (+/-0.072) for {'C': 1, 'kernel': 'rbf'}
# 	[ 2]: 0.952 (+/-0.084) for {'C': 10, 'kernel': 'linear'}
# 	[ 3]: 0.962 (+/-0.072) for {'C': 10, 'kernel': 'rbf'}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#    micro avg       0.98      0.98      0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# CTOR for best model: SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# best: dat=iris, score=0.97143, model=SVC(C=1,kernel='linear')
#
# OK

# %% [markdown]
# ### Qb Hyperparameter Grid Search using an SDG classifier
#
# Now, replace the `svm.SVC` model with an `SGDClassifier` and a suitable set of the hyperparameters for that model.
#
# You need at least four or five different hyperparameters from the `SDG` in the search-space before it begins to take considerable compute time doing the full grid search.

# %%
# TODO: Qb..
# Setup search parameters
model = SGDClassifier(random_state=46)

tuning_parameters = {
    'max_iter':[1000, 2000, 3000], 
    'tol':[1e-3, 2e-3, 5e-2],
    'epsilon': [0.1, 2.5, 3.5],
    'eta0':[0.0, 2.0, 3.0]
}

CV=5
VERBOSE=0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model, tuning_parameters, cv=CV, scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
grid_tuned.fit(X_train, y_train)
t = time()-start

# Report result
b0, m0= FullReport(grid_tuned , X_test, y_test, t)
print('OK')
# Out:
# SEARCH TIME: 0.81 sec
#
# Best model set found on train set:
#
# 	best parameters={'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	best 'f1_micro' score=0.8380952380952381
# 	best index=0
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=1000,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=46, shuffle=True, tol=0.001,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	[ 1]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.002}
# 	[ 2]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.05}
# 	[ 3]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.001}
# 	[ 4]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.002}
# 	[ 5]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.05}
# 	[ 6]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.001}
# 	[ 7]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.002}
# 	[ 8]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.05}
# 	[ 9]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.001}
# 	[10]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.002}
# 	[11]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.05}
# 	[12]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.001}
# 	[13]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.002}
# 	[14]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.05}
# 	[15]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.001}
# 	[16]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.002}
# 	[17]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.05}
# 	[18]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.001}
# 	[19]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.002}
# 	[20]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.05}
# 	[21]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.001}
# 	[22]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.002}
# 	[23]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.05}
# 	[24]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.001}
# 	[25]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.002}
# 	[26]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.05}
# 	[27]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	[28]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.002}
# 	[29]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.05}
# 	[30]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.001}
# 	[31]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.002}
# 	[32]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.05}
# 	[33]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.001}
# 	[34]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.002}
# 	[35]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.05}
# 	[36]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.001}
# 	[37]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.002}
# 	[38]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.05}
# 	[39]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.001}
# 	[40]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.002}
# 	[41]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.05}
# 	[42]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.001}
# 	[43]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.002}
# 	[44]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.05}
# 	[45]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.001}
# 	[46]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.002}
# 	[47]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.05}
# 	[48]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.001}
# 	[49]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.002}
# 	[50]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.05}
# 	[51]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.001}
# 	[52]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.002}
# 	[53]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.05}
# 	[54]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	[55]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.002}
# 	[56]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.05}
# 	[57]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.001}
# 	[58]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.002}
# 	[59]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.05}
# 	[60]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.001}
# 	[61]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.002}
# 	[62]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.05}
# 	[63]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.001}
# 	[64]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.002}
# 	[65]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.05}
# 	[66]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.001}
# 	[67]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.002}
# 	[68]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.05}
# 	[69]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.001}
# 	[70]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.002}
# 	[71]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.05}
# 	[72]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.001}
# 	[73]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.002}
# 	[74]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.05}
# 	[75]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.001}
# 	[76]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.002}
# 	[77]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.05}
# 	[78]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.001}
# 	[79]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.002}
# 	[80]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.05}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74        16
#            1       0.00      0.00      0.00        18
#            2       0.61      1.00      0.76        11
#
#    micro avg       0.60      0.60      0.60        45
#    macro avg       0.40      0.67      0.50        45
# weighted avg       0.36      0.60      0.45        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=1000,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=46, shuffle=True, tol=0.001,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# best: dat=iris, score=0.83810, model=SGDClassifier(epsilon=0.1,eta0=0.0,max_iter=1000,tol=0.001)
#
# OK
# C:\Users\Bjarke Hansen\AppData\Local\conda\conda\envs\itmal\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Qc Hyperparameter Random  Search using an SDG classifier
#
# Now, add code to run a `RandomizedSearchCV` instead.
#
# <img src="Figs/randomsearch.png" style="width:300px">
# <small><em>
#     <center> Conceptual graphical view of randomized search for two distinct hyperparameters. </center>
# </em></small>
#
# Use the same parameters for the random search, but add and investigate the new `n_iter` parameter
#
# ```python
# random_tuned = RandomizedSearchCV(model, tuning_parameters, random_state=42, n_iter=20, cv=CV, scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
# ```
#
# Comparison of time (seconds) to complete `GridSearch` versus `RandomizedSearchCV`, does not necessarily give any sense, if your grid search completes in seconds (for the iris tiny-data).
#
# But you could compare the best-tuned parameter set and best scoring for the two methods. Is the random search best model close to the grid search?

# %%
# TODO: Qc..
# Run RandomizedSearchCV for the model
start = time()
random_tuned = RandomizedSearchCV(model, tuning_parameters, random_state=46, n_iter=50, cv=CV, 
                                  scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
random_tuned.fit(X_train, y_train)
t = time()-start

# Report result
b0, m0= FullReport(grid_tuned , X_test, y_test, t)
print('OK')
# Out:
# SEARCH TIME: 0.77 sec
#
# Best model set found on train set:
#
# 	best parameters={'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	best 'f1_micro' score=0.8380952380952381
# 	best index=0
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=1000,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=46, shuffle=True, tol=0.001,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	[ 1]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.002}
# 	[ 2]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.05}
# 	[ 3]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.001}
# 	[ 4]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.002}
# 	[ 5]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.05}
# 	[ 6]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.001}
# 	[ 7]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.002}
# 	[ 8]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.05}
# 	[ 9]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.001}
# 	[10]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.002}
# 	[11]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.05}
# 	[12]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.001}
# 	[13]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.002}
# 	[14]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.05}
# 	[15]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.001}
# 	[16]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.002}
# 	[17]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.05}
# 	[18]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.001}
# 	[19]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.002}
# 	[20]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.05}
# 	[21]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.001}
# 	[22]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.002}
# 	[23]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.05}
# 	[24]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.001}
# 	[25]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.002}
# 	[26]: 0.838 (+/-0.170) for {'epsilon': 0.1, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.05}
# 	[27]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	[28]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.002}
# 	[29]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.05}
# 	[30]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.001}
# 	[31]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.002}
# 	[32]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.05}
# 	[33]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.001}
# 	[34]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.002}
# 	[35]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.05}
# 	[36]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.001}
# 	[37]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.002}
# 	[38]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.05}
# 	[39]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.001}
# 	[40]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.002}
# 	[41]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.05}
# 	[42]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.001}
# 	[43]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.002}
# 	[44]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.05}
# 	[45]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.001}
# 	[46]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.002}
# 	[47]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.05}
# 	[48]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.001}
# 	[49]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.002}
# 	[50]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.05}
# 	[51]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.001}
# 	[52]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.002}
# 	[53]: 0.838 (+/-0.170) for {'epsilon': 2.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.05}
# 	[54]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.001}
# 	[55]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.002}
# 	[56]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 1000, 'tol': 0.05}
# 	[57]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.001}
# 	[58]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.002}
# 	[59]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 2000, 'tol': 0.05}
# 	[60]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.001}
# 	[61]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.002}
# 	[62]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 0.0, 'max_iter': 3000, 'tol': 0.05}
# 	[63]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.001}
# 	[64]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.002}
# 	[65]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 1000, 'tol': 0.05}
# 	[66]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.001}
# 	[67]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.002}
# 	[68]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 2000, 'tol': 0.05}
# 	[69]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.001}
# 	[70]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.002}
# 	[71]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 2.0, 'max_iter': 3000, 'tol': 0.05}
# 	[72]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.001}
# 	[73]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.002}
# 	[74]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 1000, 'tol': 0.05}
# 	[75]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.001}
# 	[76]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.002}
# 	[77]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 2000, 'tol': 0.05}
# 	[78]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.001}
# 	[79]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.002}
# 	[80]: 0.838 (+/-0.170) for {'epsilon': 3.5, 'eta0': 3.0, 'max_iter': 3000, 'tol': 0.05}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74        16
#            1       0.00      0.00      0.00        18
#            2       0.61      1.00      0.76        11
#
#    micro avg       0.60      0.60      0.60        45
#    macro avg       0.40      0.67      0.50        45
# weighted avg       0.36      0.60      0.45        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=1000,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=46, shuffle=True, tol=0.001,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# best: dat=iris, score=0.83810, model=SGDClassifier(epsilon=0.1,eta0=0.0,max_iter=1000,tol=0.001)
#
# OK
# C:\Users\Bjarke Hansen\AppData\Local\conda\conda\envs\itmal\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Qd Search Quest
#
# Finally, we create a small competition: who can find the best model+hyperparameters for MNIST dataset?
#
# You change to the MNIST data by calling `LoadAndSetupData('mnist')`, and this is a completely other ball-game that the _tiny-data_ iris: it's much larger (but still far from _big-data_)!
#
# * You might opt for an exhaustive grid search, or a faster but-less optimal random search...your choice.
#
# * You are free to pick any classifier in Scikit-learn, even algorithms we have not discussed yet, but keep the score function at `f1_micro`, otherwise, we will be comparing 'æbler og pærer'.
#
# * And, you may also want to scale you input data for some models to perform better (neural networks in particular).
#
# * DO NOT USE Keras or Tensorflow models...not yet, and there are too many examples on the net to cut-and-paste from!
#
# Check your result by printing the first _return_ value from `FullReport()`
# ```python
# b1, m1 = FullReport(random_tuned , X_test, y_test, time_randomsearch)
# print(b1)
# ```
# that will display a result like
# ```
# best: dat=iris, score=0.97143, model=SVC(C=1, kernel='linear')
# ```
# Now, check if your score (for MNIST) is better that the currently best score on Blackboard: "L07: Optimization and searching" | "Search Quest for MNIST"
#
# > https://blackboard.au.dk/webapps/blackboard/content/listContentEditable.jsp?content_id=_2117394_1&course_id=_124256_1&content_id=_2179138_1
#
# and paste your best model into the message box, like
# ```
# best(Mr.Itmal): dat=mnist, score=0.47090, model=MLPClassifier(random_state=42, max_iter=10, activation='tanh')
# ```
# Remember to provide a _custom_ name manually, like 'best(joe)', 'best(john)' or 'best(it256)', so we can identify a winnner!
#
# For the journal, report your progress in scoring choosing different models, hyperparameters to search and how you might need to preprocess your data...

# %%
# TODO: Qd..
from sklearn.linear_model import LogisticRegression

LoadAndSetupData('mnist')


model = LogisticRegression(random_state=46, n_jobs=-1, multi_class='multinomial', penalty='l2')

tuning_parameters = { 
    'tol':[1e-4, 1e-3, 2e-3, 1e-10],
    'C': [1.0, 0.5, 1.5, 1.1, 0.9],
    'class_weight':(None, 'balanced'),
    "max_iter": (100, 200, 500),
    "solver": ('newton-cg', 'sag', 'saga', 'lbfgs')
}

CV=5
VERBOSE=0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model1 tuning_parameters, cv=CV, scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
grid_tuned.fit(X_train, y_train)
t = time()-start
# Out:
# DATA: mnist..
#   org. data:  X.shape      =(70000;  784), y.shape      =(70000)
#   train data: X_train.shape=(49000;  784), y_train.shape=(49000)
#   test data:  X_test.shape =(21000;  784), y_test.shape =(21000)
#
# SEARCH TIME: 83.22 sec
#
# Best model set found on train set:
#
# 	best parameters={'tol': 0.002, 'max_iter': 2000, 'eta0': 3.0, 'epsilon': 2.5}
# 	best 'f1_micro' score=0.8380952380952381
# 	best index=0
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=2.5, eta0=3.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=2000,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=46, shuffle=True, tol=0.002,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 2000, 'eta0': 3.0, 'epsilon': 2.5}
# 	[ 1]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 3000, 'eta0': 0.0, 'epsilon': 2.5}
# 	[ 2]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 2.5}
# 	[ 3]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 3000, 'eta0': 3.0, 'epsilon': 2.5}
# 	[ 4]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 3000, 'eta0': 3.0, 'epsilon': 0.1}
# 	[ 5]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 2000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[ 6]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[ 7]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 2000, 'eta0': 3.0, 'epsilon': 3.5}
# 	[ 8]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[ 9]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 3000, 'eta0': 3.0, 'epsilon': 0.1}
# 	[10]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 3000, 'eta0': 2.0, 'epsilon': 3.5}
# 	[11]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 1000, 'eta0': 3.0, 'epsilon': 2.5}
# 	[12]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 3000, 'eta0': 0.0, 'epsilon': 2.5}
# 	[13]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 2000, 'eta0': 2.0, 'epsilon': 2.5}
# 	[14]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 2000, 'eta0': 3.0, 'epsilon': 0.1}
# 	[15]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 2000, 'eta0': 3.0, 'epsilon': 3.5}
# 	[16]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 1000, 'eta0': 3.0, 'epsilon': 2.5}
# 	[17]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 3000, 'eta0': 2.0, 'epsilon': 2.5}
# 	[18]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 1000, 'eta0': 3.0, 'epsilon': 0.1}
# 	[19]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 3000, 'eta0': 0.0, 'epsilon': 0.1}
# 	[20]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 1000, 'eta0': 3.0, 'epsilon': 3.5}
# 	[21]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 3000, 'eta0': 3.0, 'epsilon': 3.5}
# 	[22]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 2.5}
# 	[23]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 2000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[24]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 3000, 'eta0': 0.0, 'epsilon': 2.5}
# 	[25]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 2000, 'eta0': 0.0, 'epsilon': 0.1}
# 	[26]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 2000, 'eta0': 0.0, 'epsilon': 0.1}
# 	[27]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 3000, 'eta0': 2.0, 'epsilon': 2.5}
# 	[28]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 2.5}
# 	[29]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 3000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[30]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[31]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 1000, 'eta0': 0.0, 'epsilon': 2.5}
# 	[32]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 3000, 'eta0': 3.0, 'epsilon': 0.1}
# 	[33]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 3000, 'eta0': 0.0, 'epsilon': 0.1}
# 	[34]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 2000, 'eta0': 3.0, 'epsilon': 3.5}
# 	[35]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 1000, 'eta0': 0.0, 'epsilon': 0.1}
# 	[36]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 1000, 'eta0': 3.0, 'epsilon': 3.5}
# 	[37]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 2000, 'eta0': 2.0, 'epsilon': 2.5}
# 	[38]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 3000, 'eta0': 3.0, 'epsilon': 3.5}
# 	[39]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 2000, 'eta0': 2.0, 'epsilon': 3.5}
# 	[40]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 3.5}
# 	[41]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 1000, 'eta0': 3.0, 'epsilon': 2.5}
# 	[42]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 3000, 'eta0': 2.0, 'epsilon': 3.5}
# 	[43]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 2000, 'eta0': 0.0, 'epsilon': 0.1}
# 	[44]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 3000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[45]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 2000, 'eta0': 2.0, 'epsilon': 3.5}
# 	[46]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 1000, 'eta0': 2.0, 'epsilon': 3.5}
# 	[47]: 0.838 (+/-0.170) for {'tol': 0.05, 'max_iter': 2000, 'eta0': 3.0, 'epsilon': 2.5}
# 	[48]: 0.838 (+/-0.170) for {'tol': 0.002, 'max_iter': 3000, 'eta0': 2.0, 'epsilon': 0.1}
# 	[49]: 0.838 (+/-0.170) for {'tol': 0.001, 'max_iter': 3000, 'eta0': 3.0, 'epsilon': 2.5}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74        16
#            1       0.00      0.00      0.00        18
#            2       0.61      1.00      0.76        11
#
#    micro avg       0.60      0.60      0.60        45
#    macro avg       0.40      0.67      0.50        45
# weighted avg       0.36      0.60      0.45        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=2.5, eta0=3.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=2000,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=46, shuffle=True, tol=0.002,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# best: dat=mnist, score=0.83810, model=SGDClassifier(epsilon=2.5,eta0=3.0,max_iter=2000,tol=0.002)
#
# best: dat=mnist, score=0.83810, model=SGDClassifier(epsilon=2.5,eta0=3.0,max_iter=2000,tol=0.002)
# C:\Users\Bjarke Hansen\AppData\Local\conda\conda\envs\itmal\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Bjarke Hansen\AppData\Local\conda\conda\envs\itmal\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Report results
b1, m1 = FullReport(grid_tuned , X_test, y_test, t)
print(b1)
# Out:
# SEARCH TIME: 83.22 sec
#
# Best model set found on train set:
#
# 	best parameters={'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	best 'f1_micro' score=0.9904761904761905
# 	best index=52
#
# Best estimator CTOR:
# 	LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='multinomial', n_jobs=-1, penalty='l2',
#           random_state=46, solver='sag', tol=0.0001, verbose=0,
#           warm_start=False)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[ 1]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[ 2]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[ 3]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[ 4]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[ 5]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[ 6]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[ 7]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[ 8]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[ 9]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[10]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[11]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[12]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[13]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[14]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[15]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[16]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[17]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[18]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[19]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[20]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[21]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[22]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[23]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[24]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[25]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[26]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[27]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[28]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[29]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[30]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[31]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[32]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[33]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[34]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[35]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[36]: 0.962 (+/-0.072) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[37]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[38]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[39]: 0.962 (+/-0.072) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[40]: 0.971 (+/-0.077) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[41]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[42]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[43]: 0.971 (+/-0.077) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[44]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[45]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[46]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[47]: 0.952 (+/-0.084) for {'C': 1.0, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[48]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[49]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[50]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[51]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[52]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[53]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[54]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[55]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[56]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[57]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[58]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[59]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[60]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[61]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[62]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[63]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[64]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[65]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[66]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[67]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[68]: 0.981 (+/-0.048) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[69]: 0.971 (+/-0.048) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[70]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[71]: 0.981 (+/-0.048) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[72]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[73]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[74]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[75]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[76]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[77]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[78]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[79]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[80]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[81]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[82]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[83]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[84]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[85]: 0.971 (+/-0.048) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[86]: 0.981 (+/-0.049) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[87]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[88]: 0.981 (+/-0.048) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[89]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[90]: 0.990 (+/-0.041) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[91]: 0.981 (+/-0.048) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[92]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[93]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[94]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[95]: 0.952 (+/-0.102) for {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[96]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[97]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[98]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[99]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[100]: 0.971 (+/-0.077) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[101]: 0.971 (+/-0.077) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[102]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[103]: 0.971 (+/-0.077) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[104]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[105]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[106]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[107]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[108]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[109]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[110]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[111]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[112]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[113]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[114]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[115]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[116]: 0.962 (+/-0.072) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[117]: 0.971 (+/-0.077) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[118]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[119]: 0.962 (+/-0.072) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[120]: 0.971 (+/-0.077) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[121]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[122]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[123]: 0.971 (+/-0.077) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[124]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[125]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[126]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[127]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[128]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[129]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[130]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[131]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[132]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[133]: 0.971 (+/-0.077) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[134]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[135]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[136]: 0.962 (+/-0.072) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[137]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[138]: 0.981 (+/-0.049) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[139]: 0.962 (+/-0.072) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[140]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[141]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[142]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[143]: 0.952 (+/-0.084) for {'C': 0.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[144]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[145]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[146]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[147]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[148]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[149]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[150]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[151]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[152]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[153]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[154]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[155]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[156]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[157]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[158]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[159]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[160]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[161]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[162]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[163]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[164]: 0.962 (+/-0.070) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[165]: 0.962 (+/-0.070) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[166]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[167]: 0.962 (+/-0.070) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[168]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[169]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[170]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[171]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[172]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[173]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[174]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[175]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[176]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[177]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[178]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[179]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[180]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[181]: 0.962 (+/-0.070) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[182]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[183]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[184]: 0.962 (+/-0.070) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[185]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[186]: 0.990 (+/-0.041) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[187]: 0.962 (+/-0.070) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[188]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[189]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[190]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[191]: 0.952 (+/-0.102) for {'C': 0.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[192]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[193]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[194]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[195]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[196]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[197]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[198]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[199]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[200]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[201]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[202]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[203]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[204]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[205]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[206]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[207]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[208]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[209]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[210]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[211]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[212]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[213]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[214]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[215]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[216]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[217]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[218]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[219]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[220]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[221]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[222]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[223]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[224]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[225]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[226]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[227]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[228]: 0.971 (+/-0.077) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[229]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[230]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[231]: 0.971 (+/-0.077) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[232]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[233]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[234]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[235]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[236]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[237]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[238]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[239]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[240]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[241]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[242]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[243]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[244]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[245]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[246]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[247]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[248]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[249]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[250]: 0.990 (+/-0.041) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[251]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[252]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[253]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[254]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[255]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[256]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[257]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[258]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[259]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[260]: 0.971 (+/-0.048) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[261]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[262]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[263]: 0.971 (+/-0.048) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[264]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[265]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[266]: 0.990 (+/-0.041) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[267]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[268]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[269]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[270]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[271]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[272]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[273]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[274]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[275]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[276]: 0.962 (+/-0.070) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[277]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[278]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[279]: 0.962 (+/-0.070) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[280]: 0.971 (+/-0.048) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[281]: 0.981 (+/-0.049) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[282]: 0.990 (+/-0.041) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[283]: 0.971 (+/-0.048) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[284]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[285]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[286]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[287]: 0.943 (+/-0.109) for {'C': 1.5, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[288]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[289]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[290]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[291]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[292]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[293]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[294]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[295]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[296]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[297]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[298]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[299]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[300]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[301]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[302]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[303]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[304]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[305]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[306]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[307]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[308]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[309]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[310]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[311]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[312]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[313]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[314]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[315]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[316]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[317]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[318]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[319]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[320]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[321]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[322]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[323]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[324]: 0.962 (+/-0.072) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[325]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[326]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[327]: 0.962 (+/-0.072) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[328]: 0.971 (+/-0.077) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[329]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[330]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[331]: 0.971 (+/-0.077) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[332]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[333]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[334]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[335]: 0.952 (+/-0.084) for {'C': 1.1, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[336]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[337]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[338]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[339]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[340]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[341]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[342]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[343]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[344]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[345]: 0.990 (+/-0.041) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[346]: 0.990 (+/-0.041) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[347]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[348]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[349]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[350]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[351]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[352]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[353]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[354]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[355]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[356]: 0.981 (+/-0.048) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[357]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[358]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[359]: 0.981 (+/-0.048) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[360]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[361]: 0.990 (+/-0.041) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[362]: 0.990 (+/-0.041) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[363]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[364]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[365]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[366]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[367]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[368]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[369]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[370]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[371]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[372]: 0.962 (+/-0.070) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[373]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[374]: 0.981 (+/-0.049) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[375]: 0.962 (+/-0.070) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[376]: 0.981 (+/-0.048) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[377]: 0.990 (+/-0.041) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[378]: 0.990 (+/-0.041) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[379]: 0.981 (+/-0.048) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[380]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[381]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[382]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[383]: 0.952 (+/-0.102) for {'C': 1.1, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[384]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[385]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[386]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[387]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[388]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[389]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[390]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[391]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[392]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[393]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[394]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[395]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[396]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[397]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[398]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[399]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[400]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[401]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[402]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[403]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[404]: 0.971 (+/-0.077) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[405]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[406]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[407]: 0.971 (+/-0.077) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[408]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[409]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[410]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[411]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[412]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[413]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[414]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[415]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[416]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[417]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[418]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[419]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[420]: 0.962 (+/-0.072) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[421]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[422]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[423]: 0.962 (+/-0.072) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[424]: 0.971 (+/-0.077) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[425]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[426]: 0.981 (+/-0.049) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[427]: 0.971 (+/-0.077) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[428]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[429]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[430]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[431]: 0.952 (+/-0.084) for {'C': 0.9, 'class_weight': None, 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[432]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[433]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.001}
# 	[434]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 0.002}
# 	[435]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[436]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.0001}
# 	[437]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.001}
# 	[438]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 0.002}
# 	[439]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'sag', 'tol': 1e-10}
# 	[440]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.0001}
# 	[441]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.001}
# 	[442]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 0.002}
# 	[443]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'saga', 'tol': 1e-10}
# 	[444]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[445]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.001}
# 	[446]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 0.002}
# 	[447]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 100, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[448]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[449]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.001}
# 	[450]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 0.002}
# 	[451]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[452]: 0.981 (+/-0.048) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.0001}
# 	[453]: 0.981 (+/-0.048) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.001}
# 	[454]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 0.002}
# 	[455]: 0.981 (+/-0.048) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'sag', 'tol': 1e-10}
# 	[456]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.0001}
# 	[457]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.001}
# 	[458]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 0.002}
# 	[459]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'saga', 'tol': 1e-10}
# 	[460]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[461]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.001}
# 	[462]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 0.002}
# 	[463]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'lbfgs', 'tol': 1e-10}
# 	[464]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.0001}
# 	[465]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.001}
# 	[466]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 0.002}
# 	[467]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'newton-cg', 'tol': 1e-10}
# 	[468]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.0001}
# 	[469]: 0.981 (+/-0.048) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.001}
# 	[470]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 0.002}
# 	[471]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'sag', 'tol': 1e-10}
# 	[472]: 0.971 (+/-0.075) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.0001}
# 	[473]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.001}
# 	[474]: 0.990 (+/-0.041) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 0.002}
# 	[475]: 0.971 (+/-0.075) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'saga', 'tol': 1e-10}
# 	[476]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.0001}
# 	[477]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.001}
# 	[478]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 0.002}
# 	[479]: 0.952 (+/-0.102) for {'C': 0.9, 'class_weight': 'balanced', 'max_iter': 500, 'solver': 'lbfgs', 'tol': 1e-10}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#    micro avg       0.98      0.98      0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# CTOR for best model: LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='multinomial', n_jobs=-1, penalty='l2',
#           random_state=46, solver='sag', tol=0.0001, verbose=0,
#           warm_start=False)
#
# best: dat=mnist, score=0.99048, model=LogisticRegression(C=1.0,class_weight='balanced',max_iter=100,solver='sag',tol=0.0001)
#
# best: dat=mnist, score=0.99048, model=LogisticRegression(C=1.0,class_weight='balanced',max_iter=100,solver='sag',tol=0.0001)
